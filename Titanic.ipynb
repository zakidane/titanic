# %% [markdown]
# # Titanic Classification

# %%
import numpy as np
import pandas as pd
from pylab import *
from numpy.matlib import repmat
import matplotlib 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv') #load data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum(axis=0) #seeing how many missing values for each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.corr() #to see correlations
# Out:
# C:\Users\Zaki\AppData\Local\Temp\ipykernel_30180\2371350475.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() #to see correlations
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.hist(grid=True, figsize=(14,14))
# Out:
# array([[<AxesSubplot: title={'center': 'PassengerId'}>,
#         <AxesSubplot: title={'center': 'Survived'}>,
#         <AxesSubplot: title={'center': 'Pclass'}>],
#        [<AxesSubplot: title={'center': 'Age'}>,
#         <AxesSubplot: title={'center': 'SibSp'}>,
#         <AxesSubplot: title={'center': 'Parch'}>],
#        [<AxesSubplot: title={'center': 'Fare'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
df['Sex'].replace('female',0, inplace=True)
df['Sex'].replace('male',1, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.corr()
# Out:
# C:\Users\Zaki\AppData\Local\Temp\ipykernel_30180\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.036847 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.077221 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.369226  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.093254 -0.114631
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.308247  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.189119  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096067  0.159651
#
#                 Parch      Fare
# PassengerId -0.001652  0.012658
# Survived     0.081629  0.257307
# Pclass       0.018443 -0.549500
# Sex         -0.245489 -0.182333
# Age         -0.189119  0.096067
# SibSp        0.414838  0.159651
# Parch        1.000000  0.216225
# Fare         0.216225  1.000000

# %%
plt.matshow(df.corr())
plt.show()
# Out:
# C:\Users\Zaki\AppData\Local\Temp\ipykernel_30180\2438265331.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(df.corr())

# %%
corr = df.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\Zaki\AppData\Local\Temp\ipykernel_30180\1700054467.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <style type="text/css">
# #T_4668e_row0_col0, #T_4668e_row1_col1, #T_4668e_row2_col2, #T_4668e_row3_col3, #T_4668e_row4_col4, #T_4668e_row5_col5, #T_4668e_row6_col6, #T_4668e_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4668e_row0_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_4668e_row0_col2, #T_4668e_row5_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_4668e_row0_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_4668e_row0_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_4668e_row0_col5, #T_4668e_row6_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_4668e_row0_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_4668e_row0_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_4668e_row1_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4668e_row1_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4668e_row1_col3, #T_4668e_row2_col4, #T_4668e_row2_col7, #T_4668e_row3_col1, #T_4668e_row3_col6, #T_4668e_row4_col5, #T_4668e_row5_col0, #T_4668e_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4668e_row1_col4, #T_4668e_row2_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_4668e_row1_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_4668e_row1_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_4668e_row1_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_4668e_row2_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4668e_row2_col1, #T_4668e_row6_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_4668e_row2_col3, #T_4668e_row3_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_4668e_row2_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_4668e_row3_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_4668e_row3_col4, #T_4668e_row7_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_4668e_row3_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_4668e_row3_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_4668e_row4_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4668e_row4_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_4668e_row4_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_4668e_row4_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_4668e_row4_col6, #T_4668e_row5_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4668e_row4_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_4668e_row5_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_4668e_row5_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_4668e_row5_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_4668e_row5_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_4668e_row6_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4668e_row6_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_4668e_row6_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_4668e_row6_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_4668e_row6_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_4668e_row7_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4668e_row7_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_4668e_row7_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_4668e_row7_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_4668e_row7_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# </style>
# <table id="T_4668e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4668e_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_4668e_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_4668e_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_4668e_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_4668e_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_4668e_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_4668e_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_4668e_level0_col7" class="col_heading level0 col7" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4668e_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_4668e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4668e_row0_col1" class="data row0 col1" >-0.005007</td>
#       <td id="T_4668e_row0_col2" class="data row0 col2" >-0.035144</td>
#       <td id="T_4668e_row0_col3" class="data row0 col3" >0.042939</td>
#       <td id="T_4668e_row0_col4" class="data row0 col4" >0.036847</td>
#       <td id="T_4668e_row0_col5" class="data row0 col5" >-0.057527</td>
#       <td id="T_4668e_row0_col6" class="data row0 col6" >-0.001652</td>
#       <td id="T_4668e_row0_col7" class="data row0 col7" >0.012658</td>
#     </tr>
#     <tr>
#       <th id="T_4668e_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_4668e_row1_col0" class="data row1 col0" >-0.005007</td>
#       <td id="T_4668e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4668e_row1_col2" class="data row1 col2" >-0.338481</td>
#       <td id="T_4668e_row1_col3" class="data row1 col3" >-0.543351</td>
#       <td id="T_4668e_row1_col4" class="data row1 col4" >-0.077221</td>
#       <td id="T_4668e_row1_col5" class="data row1 col5" >-0.035322</td>
#       <td id="T_4668e_row1_col6" class="data row1 col6" >0.081629</td>
#       <td id="T_4668e_row1_col7" class="data row1 col7" >0.257307</td>
#     </tr>
#     <tr>
#       <th id="T_4668e_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_4668e_row2_col0" class="data row2 col0" >-0.035144</td>
#       <td id="T_4668e_row2_col1" class="data row2 col1" >-0.338481</td>
#       <td id="T_4668e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4668e_row2_col3" class="data row2 col3" >0.131900</td>
#       <td id="T_4668e_row2_col4" class="data row2 col4" >-0.369226</td>
#       <td id="T_4668e_row2_col5" class="data row2 col5" >0.083081</td>
#       <td id="T_4668e_row2_col6" class="data row2 col6" >0.018443</td>
#       <td id="T_4668e_row2_col7" class="data row2 col7" >-0.549500</td>
#     </tr>
#     <tr>
#       <th id="T_4668e_level0_row3" class="row_heading level0 row3" >Sex</th>
#       <td id="T_4668e_row3_col0" class="data row3 col0" >0.042939</td>
#       <td id="T_4668e_row3_col1" class="data row3 col1" >-0.543351</td>
#       <td id="T_4668e_row3_col2" class="data row3 col2" >0.131900</td>
#       <td id="T_4668e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4668e_row3_col4" class="data row3 col4" >0.093254</td>
#       <td id="T_4668e_row3_col5" class="data row3 col5" >-0.114631</td>
#       <td id="T_4668e_row3_col6" class="data row3 col6" >-0.245489</td>
#       <td id="T_4668e_row3_col7" class="data row3 col7" >-0.182333</td>
#     </tr>
#     <tr>
#       <th id="T_4668e_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_4668e_row4_col0" class="data row4 col0" >0.036847</td>
#       <td id="T_4668e_row4_col1" class="data row4 col1" >-0.077221</td>
#       <td id="T_4668e_row4_col2" class="data row4 col2" >-0.369226</td>
#       <td id="T_4668e_row4_col3" class="data row4 col3" >0.093254</td>
#       <td id="T_4668e_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_4668e_row4_col5" class="data row4 col5" >-0.308247</td>
#       <td id="T_4668e_row4_col6" class="data row4 col6" >-0.189119</td>
#       <td id="T_4668e_row4_col7" class="data row4 col7" >0.096067</td>
#     </tr>
#     <tr>
#       <th id="T_4668e_level0_row5" class="row_heading level0 row5" >SibSp</th>
#       <td id="T_4668e_row5_col0" class="data row5 col0" >-0.057527</td>
#       <td id="T_4668e_row5_col1" class="data row5 col1" >-0.035322</td>
#       <td id="T_4668e_row5_col2" class="data row5 col2" >0.083081</td>
#       <td id="T_4668e_row5_col3" class="data row5 col3" >-0.114631</td>
#       <td id="T_4668e_row5_col4" class="data row5 col
